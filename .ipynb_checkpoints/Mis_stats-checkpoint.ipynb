# %%
import os
import datetime
import json

# %%
mis_stats = []

# %%
for root, dirs, files in os.walk('D:\\DCS\\Willshouse\\stats'):
    for file in files:
        if file.endswith('.lua'):
            if file != 'SlmodMetaStats.lua' and file != 'SlmodStats.lua':
                mis_stats.append(file)

# %%
stats_dates = []

# %%
mis_stats

# %%
stats_dates = []

# %%
for m in mis_stats:
    date_str = m[-28:-16]
    date = datetime.datetime.strptime(date_str, '%b %d, %Y')
    date = date.date()
    s_d = (m, date)
    stats_dates.append(s_d)

# %%
stats_dates

# %%
for m in mis_stats:
    date_str = m[-28:-16]
    date = datetime.datetime.strptime(date_str, '%b %d, %Y')
    date = date.date()
    s_d = (m,str(date))
    stats_dates.append(s_d)

# %%
stats_dates
# Out:
# [('1_Op_Longbow_Upgraded_All_Out_War- Mar 24, 2018 at 14 11 53.lua',
#   datetime.date(2018, 3, 24)),
#  ('1_Op_Longbow_Upgraded_All_Out_War- Mar 24, 2018 at 14 17 42.lua',
#   datetime.date(2018, 3, 24)),
#  ('1_Op_Longbow_Upgraded_All_Out_War- Mar 24, 2018 at 14 37 46.lua',
#   datetime.date(2018, 3, 24)),
#  ('1_Op_Longbow_Upgraded_All_Out_War- Mar 24, 2018 at 14 47 26.lua',
#   datetime.date(2018, 3, 24)),
#  ('21st NTTR Range v.1- Jun 14, 2018 at 17 43 00.lua',
#   datetime.date(2018, 6, 14)),
#  ('21st NTTR v2.1- Jun 14, 2018 at 21 01 42.lua', datetime.date(2018, 6, 14)),
#  ('21st NTTR v2.2- Jun 14, 2018 at 23 14 08.lua', datetime.date(2018, 6, 14)),
#  ('21st PG Naval Training Hawk v.57- Jun 12, 2018 at 21 49 03.lua',
#   datetime.date(2018, 6, 12)),
#  ('21st PG Naval Training Night v.57- Jun 12, 2018 at 20 27 48.lua',
#   datetime.date(2018, 6, 12)),
#  ('21st PG Naval Training v.52- Jun 02, 2018 at 22 14 31.lua',
#   datetime.date(2018, 6, 2)),
#  ('21st PG Naval Training v.52-20180531-210159- Jun 02, 2018 at 22 17 32.lua',
#   datetime.date(2018, 6, 2)),
#  ('21st PG Naval Training v.53- Jun 03, 2018 at 17 04 56.lua',
#   datetime.date(2018, 6, 3)),
#  ('21st PG Naval Training v.54- Jun 04, 2018 at 19 28 50.lua',
#   datetime.date(2018, 6, 4)),
#  ('21st PG Naval Training v.55- Jun 05, 2018 at 18 58 38.lua',
#   datetime.date(2018, 6, 5)),
#  ('21st PG Naval Training v.55- Jun 05, 2018 at 18 59 41.lua',
#   datetime.date(2018, 6, 5)),
#  ('21st PG Naval Training v.55- Jun 05, 2018 at 21 37 22.lua',
#   datetime.date(2018, 6, 5)),
#  ('21st PG Naval Training v.56- Jun 06, 2018 at 19 57 10.lua',
#   datetime.date(2018, 6, 6)),
#  ('21st PG Naval Training v.57- Jun 12, 2018 at 15 56 00.lua',
#   datetime.date(2018, 6, 12)),
#  ('21st PG Naval Training v.57- Jun 12, 2018 at 21 22 29.lua',
#   datetime.date(2018, 6, 12)),
#  ('21st PG Naval Training v.57- Jun 13, 2018 at 21 35 39.lua',
#   datetime.date(2018, 6, 13)),
#  ('21st PG Naval Training v.57- Jun 14, 2018 at 20 47 55.lua',
#   datetime.date(2018, 6, 14)),
#  ('21st PG Naval Training v.6 Missile Trainer- Jun 15, 2018 at 22 24 09.lua',
#   datetime.date(2018, 6, 15)),
#  ('21st PG Naval Training v.61 Missile Trainer- Jun 15, 2018 at 22 31 41.lua',
#   datetime.date(2018, 6, 15)),
#  ('21st PG Naval Training v.61 Missile Trainer- Jun 18, 2018 at 20 14 47.lua',
#   datetime.date(2018, 6, 18)),
#  ('21st PG Naval Training v.61 Missile Trainer- Jun 23, 2018 at 20 11 59.lua',
#   datetime.date(2018, 6, 23)),
#  ('21st PG Training v.62- Jun 26, 2018 at 18 45 53.lua',
#   datetime.date(2018, 6, 26)),
#  ('21st PG Training v.62- Jun 26, 2018 at 19 07 05.lua',
#   datetime.date(2018, 6, 26)),
#  ('21st PG Training v.62- Jun 26, 2018 at 19 28 46.lua',
#   datetime.date(2018, 6, 26)),
#  ('21st PG Training v.62- Jun 26, 2018 at 19 30 18.lua',
#   datetime.date(2018, 6, 26)),
#  ('21st PG Training v.62- Jun 26, 2018 at 19 31 56.lua',
#   datetime.date(2018, 6, 26)),
#  ('21st PG Training v.62- Jun 26, 2018 at 19 33 37.lua',
#   datetime.date(2018, 6, 26)),
#  ('21st PG Training v.62- Jun 27, 2018 at 09 27 55.lua',
#   datetime.date(2018, 6, 27)),
#  ('21st Range Debug- Apr 21, 2018 at 22 36 13.lua',
#   datetime.date(2018, 4, 21)),
#  ('21st Range v1- Apr 21, 2018 at 21 19 31.lua', datetime.date(2018, 4, 21)),
#  ('2Harrier Havadarya Power Plant- Jun 15, 2018 at 22 30 42.lua',
#   datetime.date(2018, 6, 15)),
#  ('476 NTTR P4.3-All_RangesF18- Jun 16, 2018 at 13 06 45.lua',
#   datetime.date(2018, 6, 16)),
#  ('Auto-test- Jun 16, 2018 at 14 10 56.lua', datetime.date(2018, 6, 16)),
#  ('ConvoyRandAA- Mar 13, 2018 at 21 04 19.lua', datetime.date(2018, 3, 13)),
#  ('ConvoyRandAAReload- Mar 16, 2018 at 20 21 39.lua',
#   datetime.date(2018, 3, 16)),
#  ('ConvoyRandAAReload- Mar 16, 2018 at 20 27 28.lua',
#   datetime.date(2018, 3, 16)),
#  ('F5 IFF Fam v1- Apr 11, 2018 at 21 09 20.lua', datetime.date(2018, 4, 11)),
#  ('F5 IFF Fam v2- Apr 13, 2018 at 20 38 59.lua', datetime.date(2018, 4, 13)),
#  ('HarrierTraining01- Mar 13, 2018 at 19 57 05.lua',
#   datetime.date(2018, 3, 13)),
#  ('HarrierTraining01- Mar 13, 2018 at 21 03 30.lua',
#   datetime.date(2018, 3, 13)),
#  ('HarrierTraining01- Mar 14, 2018 at 13 33 48.lua',
#   datetime.date(2018, 3, 14)),
#  ('HLLHTraining- Mar 20, 2018 at 20 47 10.lua', datetime.date(2018, 3, 20)),
#  ('HLLHTraining- Mar 20, 2018 at 20 47 24.lua', datetime.date(2018, 3, 20)),
#  ('HLLHTraining- Mar 20, 2018 at 21 27 15.lua', datetime.date(2018, 3, 20)),
#  ('HLLHTraining- Mar 20, 2018 at 21 31 22.lua', datetime.date(2018, 3, 20)),
#  ('HLLHTraining- Mar 21, 2018 at 19 02 55.lua', datetime.date(2018, 3, 21)),
#  ('HLLHTraining- Mar 21, 2018 at 19 04 40.lua', datetime.date(2018, 3, 21)),
#  ('HLLHTraining- Mar 22, 2018 at 14 44 19.lua', datetime.date(2018, 3, 22)),
#  ('HLLHTraining- Mar 22, 2018 at 21 03 25.lua', datetime.date(2018, 3, 22)),
#  ('HLLHTraining- Mar 22, 2018 at 21 16 26.lua', datetime.date(2018, 3, 22)),
#  ('HLLHTraining- Mar 22, 2018 at 23 03 03.lua', datetime.date(2018, 3, 22)),
#  ('HLLHTraining- Mar 24, 2018 at 20 03 20.lua', datetime.date(2018, 3, 24)),
#  ('IFR-XC- Apr 06, 2018 at 21 43 56.lua', datetime.date(2018, 4, 6)),
#  ('IFR-XC- Apr 07, 2018 at 20 22 34.lua', datetime.date(2018, 4, 7)),
#  ('IFR-XC- Mar 16, 2018 at 20 25 29.lua', datetime.date(2018, 3, 16)),
#  ('L-39Workups- Apr 07, 2018 at 20 34 10.lua', datetime.date(2018, 4, 7)),
#  ('L-39Workups- Apr 10, 2018 at 20 14 09.lua', datetime.date(2018, 4, 10)),
#  ('Mission01a- Jun 25, 2018 at 20 37 11.lua', datetime.date(2018, 6, 25)),
#  ('Mission01a- Jun 25, 2018 at 21 31 44.lua', datetime.date(2018, 6, 25)),
#  ('PG_SAM_tour- Jun 16, 2018 at 21 02 06.lua', datetime.date(2018, 6, 16)),
#  ('Power Plant Strike Aggressors- Jun 15, 2018 at 20 01 09.lua',
#   datetime.date(2018, 6, 15)),
#  ('PrimeShippingNotAvailable Caucuses REdux 2 LHA- Mar 25, 2018 at 20 33 07.lua',
#   datetime.date(2018, 3, 25)),
#  ('PrimeShippingNotAvailable Caucuses REdux 2 LHA- Mar 25, 2018 at 20 37 37.lua',
#   datetime.date(2018, 3, 25)),
#  ('PrimeShippingNotAvailable Caucuses REdux- Mar 20, 2018 at 21 25 36.lua',
#   datetime.date(2018, 3, 20)),
#  ('PrimeShippingNotAvailable Caucuses REdux- Mar 20, 2018 at 21 29 48.lua',
#   datetime.date(2018, 3, 20)),
#  ('PrimeShippingNotAvailable Caucuses REdux- Mar 20, 2018 at 21 32 03.lua',
#   datetime.date(2018, 3, 20)),
#  ('test- Jun 20, 2018 at 21 38 28.lua', datetime.date(2018, 6, 20)),
#  ('test- Jun 20, 2018 at 21 46 18.lua', datetime.date(2018, 6, 20)),
#  ('test- Jun 22, 2018 at 14 52 55.lua', datetime.date(2018, 6, 22)),
#  ('test- Jun 22, 2018 at 14 56 33.lua', datetime.date(2018, 6, 22)),
#  ('test- Jun 22, 2018 at 15 00 12.lua', datetime.date(2018, 6, 22)),
#  ('test- Jun 25, 2018 at 22 48 38.lua', datetime.date(2018, 6, 25)),
#  ('Through_The_Inferno_Coast_v5n-312- Mar 24, 2018 at 14 04 40.lua',
#   datetime.date(2018, 3, 24)),
#  ('Training Map - 1-20180313-205914- Mar 14, 2018 at 22 52 32.lua',
#   datetime.date(2018, 3, 14)),
#  ('Training Map - 1-20180313-205914- Mar 16, 2018 at 19 51 57.lua',
#   datetime.date(2018, 3, 16)),
#  ('Training Map - 2-20180317-204955- Mar 17, 2018 at 22 47 08.lua',
#   datetime.date(2018, 3, 17)),
#  ('Training-02RangeDay- Mar 14, 2018 at 19 09 21.lua',
#   datetime.date(2018, 3, 14)),
#  ('Viggen101- Apr 26, 2018 at 20 12 16.lua', datetime.date(2018, 4, 26)),
#  ('Viggen101- Mar 27, 2018 at 20 13 37.lua', datetime.date(2018, 3, 27)),
#  ('Viggen101- Mar 28, 2018 at 19 16 39.lua', datetime.date(2018, 3, 28)),
#  ('Viggen101- Mar 28, 2018 at 19 27 21.lua', datetime.date(2018, 3, 28)),
#  ('Viggen102- Apr 03, 2018 at 20 39 57.lua', datetime.date(2018, 4, 3)),
#  ('Viggen102- Mar 28, 2018 at 22 34 19.lua', datetime.date(2018, 3, 28)),
#  ('Viggen102- Mar 28, 2018 at 22 37 02.lua', datetime.date(2018, 3, 28)),
#  ('viggenTest- Mar 24, 2018 at 23 21 35.lua', datetime.date(2018, 3, 24)),
#  ('viggenTest-Night- Mar 24, 2018 at 23 38 05.lua',
#   datetime.date(2018, 3, 24)),
#  ('Weapons Factory Night Strike- Mar 24, 2018 at 20 08 01.lua',
#   datetime.date(2018, 3, 24)),
#  ('Weapons Factory Night Strike- Mar 25, 2018 at 20 11 28.lua',
#   datetime.date(2018, 3, 25)),
#  ('Weapons Factory Night Strike- May 16, 2018 at 20 50 02.lua',
#   datetime.date(2018, 5, 16)),
#  ('1_Op_Longbow_Upgraded_All_Out_War- Mar 24, 2018 at 14 11 53.lua',
#   datetime.date(2018, 3, 24)),
#  ('1_Op_Longbow_Upgraded_All_Out_War- Mar 24, 2018 at 14 17 42.lua',
#   datetime.date(2018, 3, 24)),
#  ('1_Op_Longbow_Upgraded_All_Out_War- Mar 24, 2018 at 14 37 46.lua',
#   datetime.date(2018, 3, 24)),
#  ('1_Op_Longbow_Upgraded_All_Out_War- Mar 24, 2018 at 14 47 26.lua',
#   datetime.date(2018, 3, 24)),
#  ('21st NTTR Range v.1- Jun 14, 2018 at 17 43 00.lua',
#   datetime.date(2018, 6, 14)),
#  ('21st NTTR v2.1- Jun 14, 2018 at 21 01 42.lua', datetime.date(2018, 6, 14)),
#  ('21st NTTR v2.2- Jun 14, 2018 at 23 14 08.lua', datetime.date(2018, 6, 14)),
#  ('21st PG Naval Training Hawk v.57- Jun 12, 2018 at 21 49 03.lua',
#   datetime.date(2018, 6, 12)),
#  ('21st PG Naval Training Night v.57- Jun 12, 2018 at 20 27 48.lua',
#   datetime.date(2018, 6, 12)),
#  ('21st PG Naval Training v.52- Jun 02, 2018 at 22 14 31.lua',
#   datetime.date(2018, 6, 2)),
#  ('21st PG Naval Training v.52-20180531-210159- Jun 02, 2018 at 22 17 32.lua',
#   datetime.date(2018, 6, 2)),
#  ('21st PG Naval Training v.53- Jun 03, 2018 at 17 04 56.lua',
#   datetime.date(2018, 6, 3)),
#  ('21st PG Naval Training v.54- Jun 04, 2018 at 19 28 50.lua',
#   datetime.date(2018, 6, 4)),
#  ('21st PG Naval Training v.55- Jun 05, 2018 at 18 58 38.lua',
#   datetime.date(2018, 6, 5)),
#  ('21st PG Naval Training v.55- Jun 05, 2018 at 18 59 41.lua',
#   datetime.date(2018, 6, 5)),
#  ('21st PG Naval Training v.55- Jun 05, 2018 at 21 37 22.lua',
#   datetime.date(2018, 6, 5)),
#  ('21st PG Naval Training v.56- Jun 06, 2018 at 19 57 10.lua',
#   datetime.date(2018, 6, 6)),
#  ('21st PG Naval Training v.57- Jun 12, 2018 at 15 56 00.lua',
#   datetime.date(2018, 6, 12)),
#  ('21st PG Naval Training v.57- Jun 12, 2018 at 21 22 29.lua',
#   datetime.date(2018, 6, 12)),
#  ('21st PG Naval Training v.57- Jun 13, 2018 at 21 35 39.lua',
#   datetime.date(2018, 6, 13)),
#  ('21st PG Naval Training v.57- Jun 14, 2018 at 20 47 55.lua',
#   datetime.date(2018, 6, 14)),
#  ('21st PG Naval Training v.6 Missile Trainer- Jun 15, 2018 at 22 24 09.lua',
#   datetime.date(2018, 6, 15)),
#  ('21st PG Naval Training v.61 Missile Trainer- Jun 15, 2018 at 22 31 41.lua',
#   datetime.date(2018, 6, 15)),
#  ('21st PG Naval Training v.61 Missile Trainer- Jun 18, 2018 at 20 14 47.lua',
#   datetime.date(2018, 6, 18)),
#  ('21st PG Naval Training v.61 Missile Trainer- Jun 23, 2018 at 20 11 59.lua',
#   datetime.date(2018, 6, 23)),
#  ('21st PG Training v.62- Jun 26, 2018 at 18 45 53.lua',
#   datetime.date(2018, 6, 26)),
#  ('21st PG Training v.62- Jun 26, 2018 at 19 07 05.lua',
#   datetime.date(2018, 6, 26)),
#  ('21st PG Training v.62- Jun 26, 2018 at 19 28 46.lua',
#   datetime.date(2018, 6, 26)),
#  ('21st PG Training v.62- Jun 26, 2018 at 19 30 18.lua',
#   datetime.date(2018, 6, 26)),
#  ('21st PG Training v.62- Jun 26, 2018 at 19 31 56.lua',
#   datetime.date(2018, 6, 26)),
#  ('21st PG Training v.62- Jun 26, 2018 at 19 33 37.lua',
#   datetime.date(2018, 6, 26)),
#  ('21st PG Training v.62- Jun 27, 2018 at 09 27 55.lua',
#   datetime.date(2018, 6, 27)),
#  ('21st Range Debug- Apr 21, 2018 at 22 36 13.lua',
#   datetime.date(2018, 4, 21)),
#  ('21st Range v1- Apr 21, 2018 at 21 19 31.lua', datetime.date(2018, 4, 21)),
#  ('2Harrier Havadarya Power Plant- Jun 15, 2018 at 22 30 42.lua',
#   datetime.date(2018, 6, 15)),
#  ('476 NTTR P4.3-All_RangesF18- Jun 16, 2018 at 13 06 45.lua',
#   datetime.date(2018, 6, 16)),
#  ('Auto-test- Jun 16, 2018 at 14 10 56.lua', datetime.date(2018, 6, 16)),
#  ('ConvoyRandAA- Mar 13, 2018 at 21 04 19.lua', datetime.date(2018, 3, 13)),
#  ('ConvoyRandAAReload- Mar 16, 2018 at 20 21 39.lua',
#   datetime.date(2018, 3, 16)),
#  ('ConvoyRandAAReload- Mar 16, 2018 at 20 27 28.lua',
#   datetime.date(2018, 3, 16)),
#  ('F5 IFF Fam v1- Apr 11, 2018 at 21 09 20.lua', datetime.date(2018, 4, 11)),
#  ('F5 IFF Fam v2- Apr 13, 2018 at 20 38 59.lua', datetime.date(2018, 4, 13)),
#  ('HarrierTraining01- Mar 13, 2018 at 19 57 05.lua',
#   datetime.date(2018, 3, 13)),
#  ('HarrierTraining01- Mar 13, 2018 at 21 03 30.lua',
#   datetime.date(2018, 3, 13)),
#  ('HarrierTraining01- Mar 14, 2018 at 13 33 48.lua',
#   datetime.date(2018, 3, 14)),
#  ('HLLHTraining- Mar 20, 2018 at 20 47 10.lua', datetime.date(2018, 3, 20)),
#  ('HLLHTraining- Mar 20, 2018 at 20 47 24.lua', datetime.date(2018, 3, 20)),
#  ('HLLHTraining- Mar 20, 2018 at 21 27 15.lua', datetime.date(2018, 3, 20)),
#  ('HLLHTraining- Mar 20, 2018 at 21 31 22.lua', datetime.date(2018, 3, 20)),
#  ('HLLHTraining- Mar 21, 2018 at 19 02 55.lua', datetime.date(2018, 3, 21)),
#  ('HLLHTraining- Mar 21, 2018 at 19 04 40.lua', datetime.date(2018, 3, 21)),
#  ('HLLHTraining- Mar 22, 2018 at 14 44 19.lua', datetime.date(2018, 3, 22)),
#  ('HLLHTraining- Mar 22, 2018 at 21 03 25.lua', datetime.date(2018, 3, 22)),
#  ('HLLHTraining- Mar 22, 2018 at 21 16 26.lua', datetime.date(2018, 3, 22)),
#  ('HLLHTraining- Mar 22, 2018 at 23 03 03.lua', datetime.date(2018, 3, 22)),
#  ('HLLHTraining- Mar 24, 2018 at 20 03 20.lua', datetime.date(2018, 3, 24)),
#  ('IFR-XC- Apr 06, 2018 at 21 43 56.lua', datetime.date(2018, 4, 6)),
#  ('IFR-XC- Apr 07, 2018 at 20 22 34.lua', datetime.date(2018, 4, 7)),
#  ('IFR-XC- Mar 16, 2018 at 20 25 29.lua', datetime.date(2018, 3, 16)),
#  ('L-39Workups- Apr 07, 2018 at 20 34 10.lua', datetime.date(2018, 4, 7)),
#  ('L-39Workups- Apr 10, 2018 at 20 14 09.lua', datetime.date(2018, 4, 10)),
#  ('Mission01a- Jun 25, 2018 at 20 37 11.lua', datetime.date(2018, 6, 25)),
#  ('Mission01a- Jun 25, 2018 at 21 31 44.lua', datetime.date(2018, 6, 25)),
#  ('PG_SAM_tour- Jun 16, 2018 at 21 02 06.lua', datetime.date(2018, 6, 16)),
#  ('Power Plant Strike Aggressors- Jun 15, 2018 at 20 01 09.lua',
#   datetime.date(2018, 6, 15)),
#  ('PrimeShippingNotAvailable Caucuses REdux 2 LHA- Mar 25, 2018 at 20 33 07.lua',
#   datetime.date(2018, 3, 25)),
#  ('PrimeShippingNotAvailable Caucuses REdux 2 LHA- Mar 25, 2018 at 20 37 37.lua',
#   datetime.date(2018, 3, 25)),
#  ('PrimeShippingNotAvailable Caucuses REdux- Mar 20, 2018 at 21 25 36.lua',
#   datetime.date(2018, 3, 20)),
#  ('PrimeShippingNotAvailable Caucuses REdux- Mar 20, 2018 at 21 29 48.lua',
#   datetime.date(2018, 3, 20)),
#  ('PrimeShippingNotAvailable Caucuses REdux- Mar 20, 2018 at 21 32 03.lua',
#   datetime.date(2018, 3, 20)),
#  ('test- Jun 20, 2018 at 21 38 28.lua', datetime.date(2018, 6, 20)),
#  ('test- Jun 20, 2018 at 21 46 18.lua', datetime.date(2018, 6, 20)),
#  ('test- Jun 22, 2018 at 14 52 55.lua', datetime.date(2018, 6, 22)),
#  ('test- Jun 22, 2018 at 14 56 33.lua', datetime.date(2018, 6, 22)),
#  ('test- Jun 22, 2018 at 15 00 12.lua', datetime.date(2018, 6, 22)),
#  ('test- Jun 25, 2018 at 22 48 38.lua', datetime.date(2018, 6, 25)),
#  ('Through_The_Inferno_Coast_v5n-312- Mar 24, 2018 at 14 04 40.lua',
#   datetime.date(2018, 3, 24)),
#  ('Training Map - 1-20180313-205914- Mar 14, 2018 at 22 52 32.lua',
#   datetime.date(2018, 3, 14)),
#  ('Training Map - 1-20180313-205914- Mar 16, 2018 at 19 51 57.lua',
#   datetime.date(2018, 3, 16)),
#  ('Training Map - 2-20180317-204955- Mar 17, 2018 at 22 47 08.lua',
#   datetime.date(2018, 3, 17)),
#  ('Training-02RangeDay- Mar 14, 2018 at 19 09 21.lua',
#   datetime.date(2018, 3, 14)),
#  ('Viggen101- Apr 26, 2018 at 20 12 16.lua', datetime.date(2018, 4, 26)),
#  ('Viggen101- Mar 27, 2018 at 20 13 37.lua', datetime.date(2018, 3, 27)),
#  ('Viggen101- Mar 28, 2018 at 19 16 39.lua', datetime.date(2018, 3, 28)),
#  ('Viggen101- Mar 28, 2018 at 19 27 21.lua', datetime.date(2018, 3, 28)),
#  ('Viggen102- Apr 03, 2018 at 20 39 57.lua', datetime.date(2018, 4, 3)),
#  ('Viggen102- Mar 28, 2018 at 22 34 19.lua', datetime.date(2018, 3, 28)),
#  ('Viggen102- Mar 28, 2018 at 22 37 02.lua', datetime.date(2018, 3, 28)),
#  ('viggenTest- Mar 24, 2018 at 23 21 35.lua', datetime.date(2018, 3, 24)),
#  ('viggenTest-Night- Mar 24, 2018 at 23 38 05.lua',
#   datetime.date(2018, 3, 24)),
#  ('Weapons Factory Night Strike- Mar 24, 2018 at 20 08 01.lua',
#   datetime.date(2018, 3, 24)),
#  ('Weapons Factory Night Strike- Mar 25, 2018 at 20 11 28.lua',
#   datetime.date(2018, 3, 25)),
#  ('Weapons Factory Night Strike- May 16, 2018 at 20 50 02.lua',
#   datetime.date(2018, 5, 16))]

# %%
mis_stats_json = json.dumps(stats_dates, default=str, indent=4)

# %%
print(mis_stats_json)

# %%
mis_stats_file = open('slmod\\mis_stats.json', mode='w')

# %%
mis_stats_file.write(mis_stats_json)
mis_stats_file.close()

# %%
mystring = '1_Op_Longbow_Upgraded_All_Out_War- Mar 24, 2018 at 14 11 53.lua'

# %%
mystring[:-30]
